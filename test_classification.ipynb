# %% [markdown]
# <a href="https://colab.research.google.com/github/Kaiwen-d/ML-project/blob/main/test_classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from os import chdir, listdir

print(listdir('./'))

chdir('/content/drive/MyDrive/Sem_3/ML/F20_ML_final_project/preprocessing/dataset')

print(listdir('./'))
# Out:
# ['.config', 'drive', 'sample_data']
# ['.DS_Store', 'annotations', 'images', 'obj_dict_1122.dat', 'obj_dict.dat', 'obj_dict_1123.dat']

# %%
import pickle

data_dict = pickle.load(open('./obj_dict.dat', 'rb'))

dataset = data_dict['added_filter_20_dataset']

print(dataset.keys())
print(type(dataset['data']), dataset['data'][0].keys())
print(type(dataset['label_idx']), dataset['label_idx'])
# Out:
# dict_keys(['data', 'label_idx'])
# <class 'list'> dict_keys(['face', 'label'])
# ...

# %%
import matplotlib.pyplot as plt
from random import randint

print('all', len(dataset['data']))
for k, v in dataset['label_idx'].items():
    print(k, len(v))

print('\n')

idx = randint(0, 2276)
print(idx, dataset['data'][idx]['label'])
plt.imshow(dataset['data'][idx]['face'])
# Out:
# all 2277
# with_mask 1811
# without_mask 308
# mask_weared_incorrect 158
#
#
# 438 with_mask
