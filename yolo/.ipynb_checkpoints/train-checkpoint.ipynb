# %% [markdown]
# **Train YOLO model**
#
# Original Author: Bubbliiiing
#
# Edit / Rewrite / Comment By: Hammond Liu (hl3797)
#
# Github Link: [yolov4-pytorch](https://github.com/bubbliiiing/yolov4-pytorch)

# %%
# # Mount to Google Drive to train on Colab
# from google.colab import drive
# drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# The working path of this code file should be inside the yolo folder
from os import chdir, listdir

print(listdir('./'))

# chdir('/content/drive/MyDrive/Sem_3/ML/F20_ML_final_project/yolo/')
# print(listdir('./'))
# Out:
# ['.ipynb_checkpoints', 'annotation_preprocess.ipynb', 'data', 'eval.ipynb', 'loss_data', 'map', 'nets', 'predict.ipynb', 'test_img', 'train.ipynb', 'utils', 'yolo.py', '__pycache__']

# %%
import os
import time
import copy
import torch
import numpy as np
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import matplotlib.pyplot as plt
from torch.autograd import Variable
import torch.backends.cudnn as cudnn
from nets.yolo4 import YoloBody
from nets.yolo_training import YOLOLoss, Generator

# %%
# Read the format data info from input files

# = = = = = = = = = = Code Citation Start = = = = = = = = = = #
#                                                             #
#  The code here are implemented by the cited Github project. #
#  Gitgub Project Path: /yolov4-pytorch/blob/master/train.py  #
#                                                             #
def get_classes(classes_path):
    '''loads the classes'''
    with open(classes_path) as f:
        class_names = f.readlines()
    class_names = [c.strip() for c in class_names]
    return class_names

def get_anchors(anchors_path):
    '''loads the anchors from a file'''
    with open(anchors_path) as f:
        anchors = f.readline()
    anchors = [float(x) for x in anchors.split(',')]
    return np.array(anchors).reshape([-1,3,2])[::-1,:,:]
#                                                             #
# = = = = = = = = = = Code Citation End = = = = = = = = = = = #

anchors_path = './data/anchors.txt'
classes_path = './data/classes.txt'   
class_names = get_classes(classes_path)
anchors = get_anchors(anchors_path)
num_classes = len(class_names)

# %%
# Train one epoch

# = = = = = = = = = = = = Code Citation Start = = = = = = = = = = = = #
#                                                                     #
#     Key steps of this function are implemented in cited project.    #
#     We rewrite a few parts to fit the need of our project.          #
#     Gitgub Project Path: /yolov4-pytorch/blob/master/train.py       #
#                                                                     #
def fit_one_epoch(net, yolo_losses, epoch, epoch_size, epoch_size_val, gen,genval, Epoch, cuda, optimizer, lr_scheduler):
    total_loss = 0
    val_loss = 0
    print('\n' + '-' * 10 + 'Train one epoch.' + '-' * 10)
    print('Epoch:'+ str(epoch+1) + '/' + str(Epoch))
    print('Start Training.')
    net.train()
    for iteration in range(epoch_size):
        start_time = time.time()
        images, targets = next(gen)
        with torch.no_grad():
            if cuda:
                images = Variable(torch.from_numpy(images).type(torch.FloatTensor)).cuda()
                targets = [Variable(torch.from_numpy(ann).type(torch.FloatTensor)) for ann in targets]
            else:
                images = Variable(torch.from_numpy(images).type(torch.FloatTensor))
                targets = [Variable(torch.from_numpy(ann).type(torch.FloatTensor)) for ann in targets]
        optimizer.zero_grad()
        outputs = net(images)
        losses = []
        for i in range(3):
            loss_item = yolo_losses[i](outputs[i], targets)
            losses.append(loss_item[0])
        loss = sum(losses)
        loss.backward()
        optimizer.step()
        lr_scheduler.step()

        total_loss += loss
        waste_time = time.time() - start_time
        if iteration == 0 or (iteration+1) % 10 == 0:
            print(('step: %02d' % (iteration+1)) + '/' + str(epoch_size) + ' || Total Loss: %.4f || %.4fs/step' % (total_loss/(iteration+1), waste_time))
    print('Finish Training.')
            
    print('Start Validation.')
    net.eval()
    for iteration in range(epoch_size_val):
        images_val, targets_val = next(genval)

        with torch.no_grad():
            if cuda:
                images_val = Variable(torch.from_numpy(images_val).type(torch.FloatTensor)).cuda()
                targets_val = [Variable(torch.from_numpy(ann).type(torch.FloatTensor)) for ann in targets_val]
            else:
                images_val = Variable(torch.from_numpy(images_val).type(torch.FloatTensor))
                targets_val = [Variable(torch.from_numpy(ann).type(torch.FloatTensor)) for ann in targets_val]
            optimizer.zero_grad()
            outputs = net(images_val)
            losses = []
            for i in range(3):
                loss_item = yolo_losses[i](outputs[i], targets_val)
                losses.append(loss_item[0])
            loss = sum(losses)
            val_loss += loss
    print('Finish Validation')
    
    print('Total Loss: %.4f || Val Loss: %.4f ' % (total_loss/(epoch_size+1), val_loss/(epoch_size_val+1)))
    
    return total_loss/(epoch_size+1), val_loss/(epoch_size_val+1)

#                                                                     #
# = = = = = = = = = = = = Code Citation End = = = = = = = = = = = = = #

# %%
# Initialize variables

# = = = = = = = = = = = = Code Citation Start = = = = = = = = = = = = #
#                                                                     #
#     Here, we followed the parameter settings in the cited project.  #
#     Gitgub Project Path: /yolov4-pytorch/blob/master/train.py       #
#                                                                     #

input_shape = (416,416)

# Apply [cosine lr decay] and [mosaic data augment]
Cosine_lr = True
mosaic = True

Cuda = True
smoooth_label = 0.03

#                                                                     #
# = = = = = = = = = = = = Code Citation End = = = = = = = = = = = = = #

train_annotation_path = './data/train_data.txt'
val_annotation_path = './data/val_data.txt'

# %%
# = = = = = = = = = = = = Code Citation Start = = = = = = = = = = = = #
#                                                                     #
#     The code here are implemented by the cited Github project.      #
#     Gitgub Project Path: /yolov4-pytorch/blob/master/train.py       #
#                                                                     #

# Create the model & Load pretrained weights
model = YoloBody(len(anchors[0]), num_classes)


model_path = "./data/yolov4_test.pth"
# model_path = "./data/yolov4_coco_pretrained_weights.pth"
print('Loading pretrained model weights.')
model_dict = model.state_dict()
pretrained_dict = torch.load(model_path)
pretrained_dict = {k: v for k, v in pretrained_dict.items() if np.shape(model_dict[k]) ==  np.shape(v)}
model_dict.update(pretrained_dict)
model.load_state_dict(model_dict)
print('Finished!')

# Use cuda for training
if Cuda:
    net = torch.nn.DataParallel(model)
    cudnn.benchmark = True
    net = net.cuda()

# Set up YOLO loss function
yolo_losses = []
for i in range(3):
    yolo_losses.append(YOLOLoss(np.reshape(anchors, [-1,2]), num_classes, \
                                (input_shape[1], input_shape[0]), smoooth_label, Cuda))
    
#                                                                     #
# = = = = = = = = = = = = Code Citation End = = = = = = = = = = = = = #

# Read train & val data
with open(train_annotation_path) as f:
    train_lines = f.readlines()
with open(val_annotation_path) as f:
    val_lines = f.readlines()
num_train = len(train_lines)
num_val = len(val_lines)
# Out:
# Loading pretrained model weights.
# Finished!

# %%
# = = = = = = = = = = = = Code Citation Start = = = = = = = = = = = = #
#                                                                     #
#   Key steps of this function are implemented in cited project,      #
#   then we rewrite quite a lot to fit the need of our project.       #
#   Gitgub Project Path: /yolov4-pytorch/blob/master/train.py         #
#                                                                     #

def train(param_str, lr1 = 1e-3, lr2 = 1e-4, Batch_size1 = 4, Batch_size2 = 2, Init_Epoch = 0, Freeze_Epoch = 20, Unfreeze_Epoch = 40, dump_half = False):
    
    # Use Adam optimization & Apply cosine annealing lr
    optimizer = optim.Adam(net.parameters(), lr1, weight_decay = 5e-4)
    # optimizer = optim.SGD(net.parameters(), lr1, weight_decay = 5e-4)
    if Cosine_lr:
        lr_scheduler = optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=5, eta_min=1e-5)
    else:
        lr_scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=1, gamma=0.9)

    # Apply mosaic data augment
    gen = Generator(Batch_size1, train_lines, (input_shape[0], input_shape[1])).generate(mosaic = mosaic)
    gen_val = Generator(Batch_size1, val_lines, (input_shape[0], input_shape[1])).generate(mosaic = False)

    # Compute epoch size & Set requires_grad
    epoch_size = int(max(1, num_train // Batch_size1 // 2.5)) if mosaic else max(1, num_train // Batch_size1)
    epoch_size_val = num_val // Batch_size1
    for param in model.backbone.parameters():
        param.requires_grad = False

    # Training
    best_loss = 10e8
    val_loss_list = []
    train_loss_list = []
    best_model_weights = copy.deepcopy(net.state_dict())

    for epoch in range(Init_Epoch, Freeze_Epoch):
        # Fit one epoch
        total_loss, val_loss = fit_one_epoch(net, yolo_losses, epoch, epoch_size, epoch_size_val, gen, gen_val, 
                                            Freeze_Epoch, Cuda, optimizer, lr_scheduler)
        # Update the best loss if needed
        if total_loss < best_loss:
            best_loss = total_loss
            best_model_weights = copy.deepcopy(model.state_dict())
        
        # Record the loss data
        train_loss_list.append(str(total_loss.item()))
        val_loss_list.append(str(val_loss.item()))

    if dump_half:
        torch.save(best_model_weights, './data/yolo_fmd_' + param_str + '_half.pth')

    # Use Adam optimization & Apply cosine annealing lr
    optimizer = optim.Adam(net.parameters(), lr2, weight_decay=5e-4)
    # optimizer = optim.SGD(net.parameters(), lr2, weight_decay = 5e-4)
    if Cosine_lr:
        lr_scheduler = optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=5, eta_min=1e-5)
    else:
        lr_scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=1, gamma=0.9)

    # Apply mosaic data augment
    gen = Generator(Batch_size2, train_lines, (input_shape[0], input_shape[1])).generate(mosaic = mosaic)
    gen_val = Generator(Batch_size2, val_lines, (input_shape[0], input_shape[1])).generate(mosaic = False)

    # Compute epoch size & Set requires_grad    
    epoch_size = int(max(1, num_train // Batch_size2 // 2.5)) if mosaic else max(1, num_train // Batch_size2)
    epoch_size_val = num_val // Batch_size2
    for param in model.backbone.parameters():
        param.requires_grad = True

    # Training the second half
    for epoch in range(Freeze_Epoch, Unfreeze_Epoch):
        # Fit one epoch
        total_loss, val_loss = fit_one_epoch(net, yolo_losses, epoch, epoch_size, epoch_size_val, gen, gen_val, 
                                            Unfreeze_Epoch, Cuda, optimizer, lr_scheduler)
        # Update the best loss (if needed)
        if total_loss < best_loss:
            best_loss = total_loss
            best_model_weights = copy.deepcopy(model.state_dict())

        # Record the loss data
        train_loss_list.append(str(total_loss.item()))
        val_loss_list.append(str(val_loss.item()))

    with open('./loss_data/total_loss_' + param_str + '.csv', mode='w') as total_loss_file:
        total_loss_file.write('\n'.join(train_loss_list))
    with open('./loss_data/val_loss_' + param_str + '.csv', mode='w') as val_loss_file:
        val_loss_file.write('\n'.join(val_loss_list))

    # Save the final weights
    torch.save(best_model_weights, './data/yolo_fmd_' + param_str + '.pth')

#                                                                     #
# = = = = = = = = = = = = Code Citation End = = = = = = = = = = = = = #

# %%
# Call the train function can start training by default params

# train('adam_cs_40', Freeze_Epoch = 1, Unfreeze_Epoch = 2)

train('adam_cs_40')
# Out:
# ----------Train one epoch.----------
# Epoch:1/20
# Start Training.
# step: 01/46 || Total Loss: 7164.4771 || 0.9976s/step
# step: 10/46 || Total Loss: 5579.2422 || 0.8422s/step
# step: 20/46 || Total Loss: 4423.8154 || 0.8212s/step
# step: 30/46 || Total Loss: 3570.2112 || 0.8892s/step
# step: 40/46 || Total Loss: 2952.5696 || 0.7249s/step
# Finish Validation
# Total Loss: 2606.6470 || Val Loss: 624.8618
#
# ----------Train one epoch.----------
# Epoch:2/20
# Start Training.
# step: 01/46 || Total Loss: 691.2797 || 0.7325s/step
# step: 10/46 || Total Loss: 581.6378 || 0.7793s/step
# step: 20/46 || Total Loss: 512.1458 || 0.8224s/step
# step: 30/46 || Total Loss: 458.1548 || 0.7062s/step
# step: 40/46 || Total Loss: 419.3497 || 0.8001s/step
# Finish Training.
# Start Validation.
# Finish Validation
# Total Loss: 391.1996 || Val Loss: 204.6994
#
# ----------Train one epoch.----------
# Epoch:3/20
# Start Training.
# step: 01/46 || Total Loss: 247.4144 || 0.7941s/step
# step: 10/46 || Total Loss: 237.4901 || 0.7535s/step
# step: 20/46 || Total Loss: 221.2822 || 0.7603s/step
# step: 30/46 || Total Loss: 210.0345 || 0.8826s/step
# step: 40/46 || Total Loss: 198.5258 || 0.6595s/step
# Finish Training.
# Start Validation.
# Finish Validation
# Total Loss: 188.1429 || Val Loss: 135.5401
#
# ----------Train one epoch.----------
# Epoch:4/20
# Start Training.
# step: 01/46 || Total Loss: 191.9046 || 0.8767s/step
# step: 10/46 || Total Loss: 157.2949 || 0.7810s/step
# step: 20/46 || Total Loss: 144.7880 || 0.7677s/step
# step: 30/46 || Total Loss: 137.4218 || 0.7456s/step
# step: 40/46 || Total Loss: 132.0392 || 0.8489s/step
# Finish Training.
# Start Validation.
# Finish Validation
# Total Loss: 126.9350 || Val Loss: 89.9057
#
# ----------Train one epoch.----------
# Epoch:5/20
# Start Training.
# step: 01/46 || Total Loss: 98.0864 || 0.9059s/step
# step: 10/46 || Total Loss: 114.4831 || 0.8700s/step
# step: 20/46 || Total Loss: 106.9739 || 0.7084s/step
# step: 30/46 || Total Loss: 103.5075 || 0.7305s/step
# step: 40/46 || Total Loss: 101.8721 || 0.8040s/step
# Finish Training.
# Start Validation.
# Finish Validation
# Total Loss: 96.9245 || Val Loss: 66.8186
#
# ----------Train one epoch.----------
# Epoch:6/20
# Start Training.
# step: 01/46 || Total Loss: 113.5219 || 0.8426s/step
# step: 10/46 || Total Loss: 91.4877 || 0.7179s/step
# step: 20/46 || Total Loss: 89.6787 || 0.7490s/step
# step: 30/46 || Total Loss: 84.5885 || 0.8334s/step
# step: 40/46 || Total Loss: 81.1712 || 0.7922s/step
# Finish Training.
# Start Validation.
# Finish Validation
# Total Loss: 77.9261 || Val Loss: 51.7933
#
# ----------Train one epoch.----------
# Epoch:7/20
# Start Training.
# step: 01/46 || Total Loss: 59.5185 || 0.7747s/step
# step: 10/46 || Total Loss: 67.0460 || 0.7892s/step
# step: 20/46 || Total Loss: 65.1226 || 0.7970s/step
# step: 30/46 || Total Loss: 63.0477 || 0.8081s/step
# step: 40/46 || Total Loss: 63.0481 || 0.7277s/step
# Finish Training.
# Start Validation.
# Finish Validation
# Total Loss: 59.8778 || Val Loss: 42.5505
#
# ----------Train one epoch.----------
# Epoch:8/20
# Start Training.
# step: 01/46 || Total Loss: 43.9447 || 0.6671s/step
# step: 10/46 || Total Loss: 55.9284 || 0.7135s/step
# step: 20/46 || Total Loss: 52.3730 || 0.8147s/step
# step: 30/46 || Total Loss: 50.7973 || 0.7475s/step
# step: 40/46 || Total Loss: 51.3602 || 0.8433s/step
# Finish Training.
# Start Validation.
# Finish Validation
# Total Loss: 50.0570 || Val Loss: 35.5258
#
# ----------Train one epoch.----------
# Epoch:9/20
# Start Training.
# step: 01/46 || Total Loss: 42.5594 || 0.8271s/step
# step: 10/46 || Total Loss: 43.5004 || 0.7793s/step
# step: 20/46 || Total Loss: 46.1145 || 0.8576s/step
# step: 30/46 || Total Loss: 47.5366 || 0.8612s/step
# step: 40/46 || Total Loss: 46.3637 || 0.8144s/step
# Finish Training.
# Start Validation.
# Finish Validation
# Total Loss: 45.1134 || Val Loss: 30.3734
#
# ----------Train one epoch.----------
# Epoch:10/20
# Start Training.
# step: 01/46 || Total Loss: 45.0319 || 0.8423s/step
# step: 10/46 || Total Loss: 43.7015 || 0.7692s/step
# step: 20/46 || Total Loss: 43.5167 || 0.7957s/step
# step: 30/46 || Total Loss: 43.5546 || 0.8869s/step
# step: 40/46 || Total Loss: 43.6458 || 0.8237s/step
# Finish Training.
# Start Validation.
# Finish Validation
# Total Loss: 42.6690 || Val Loss: 28.3364
#
# ----------Train one epoch.----------
# Epoch:11/20
# Start Training.
# step: 01/46 || Total Loss: 29.9298 || 0.7460s/step
# step: 10/46 || Total Loss: 37.4083 || 0.8296s/step
# step: 20/46 || Total Loss: 39.0513 || 0.8064s/step
# step: 30/46 || Total Loss: 37.8919 || 0.7664s/step
# step: 40/46 || Total Loss: 36.5861 || 0.7292s/step
# Finish Training.
# Start Validation.
# Finish Validation
# Total Loss: 36.1736 || Val Loss: 24.6092
#
# ----------Train one epoch.----------
# Epoch:12/20
# Start Training.
# step: 01/46 || Total Loss: 68.3586 || 0.8649s/step
# step: 10/46 || Total Loss: 36.6975 || 0.8563s/step
# step: 20/46 || Total Loss: 34.5486 || 0.8198s/step
# step: 30/46 || Total Loss: 34.4351 || 0.7236s/step
# step: 40/46 || Total Loss: 34.1465 || 0.7709s/step
# Finish Training.
# Start Validation.
# Finish Validation
# Total Loss: 33.9108 || Val Loss: 22.0174
#
# ----------Train one epoch.----------
# Epoch:13/20
# Start Training.
# step: 01/46 || Total Loss: 33.8283 || 0.7998s/step
# step: 10/46 || Total Loss: 42.5033 || 0.7954s/step
# step: 20/46 || Total Loss: 39.5263 || 0.8103s/step
# step: 30/46 || Total Loss: 36.0094 || 0.5904s/step
# step: 40/46 || Total Loss: 34.0751 || 0.8574s/step
# Finish Training.
# Start Validation.
# Finish Validation
# Total Loss: 32.0029 || Val Loss: 19.1409
#
# ----------Train one epoch.----------
# Epoch:14/20
# Start Training.
# step: 01/46 || Total Loss: 26.7146 || 0.8305s/step
# step: 10/46 || Total Loss: 31.3937 || 0.8296s/step
# step: 20/46 || Total Loss: 35.3522 || 0.9906s/step
# step: 30/46 || Total Loss: 35.2821 || 0.7177s/step
# step: 40/46 || Total Loss: 34.2228 || 0.7412s/step
# Finish Training.
# Start Validation.
# Finish Validation
# Total Loss: 32.5490 || Val Loss: 18.7125
#
# ----------Train one epoch.----------
# Epoch:15/20
# Start Training.
# step: 01/46 || Total Loss: 25.2256 || 0.7904s/step
# step: 10/46 || Total Loss: 25.6659 || 0.7733s/step
# step: 20/46 || Total Loss: 25.9596 || 0.8475s/step
# step: 30/46 || Total Loss: 26.5543 || 0.8419s/step
# step: 40/46 || Total Loss: 25.8701 || 0.7758s/step
# Finish Training.
# Start Validation.
# Finish Validation
# Total Loss: 26.6176 || Val Loss: 16.7786
#
# ----------Train one epoch.----------
# Epoch:16/20
# Start Training.
# step: 01/46 || Total Loss: 26.8709 || 0.7859s/step
# step: 10/46 || Total Loss: 32.5338 || 1.0787s/step
# step: 20/46 || Total Loss: 30.7192 || 0.7761s/step
# step: 30/46 || Total Loss: 29.0479 || 0.8514s/step
# step: 40/46 || Total Loss: 28.0605 || 0.7134s/step
# Finish Training.
# Start Validation.
# Finish Validation
# Total Loss: 26.8670 || Val Loss: 16.1138
#
# ----------Train one epoch.----------
# Epoch:17/20
# Start Training.
# step: 01/46 || Total Loss: 27.9638 || 0.8929s/step
# step: 10/46 || Total Loss: 26.5730 || 0.8124s/step
# step: 20/46 || Total Loss: 26.2600 || 0.7177s/step
# step: 30/46 || Total Loss: 25.7777 || 0.8206s/step
# step: 40/46 || Total Loss: 25.3572 || 0.7765s/step
# Finish Training.
# Start Validation.
# Finish Validation
# Total Loss: 24.3869 || Val Loss: 16.0725
#
# ----------Train one epoch.----------
# Epoch:18/20
# Start Training.
# step: 01/46 || Total Loss: 23.6841 || 0.8031s/step
# step: 10/46 || Total Loss: 24.9510 || 0.7622s/step
# step: 20/46 || Total Loss: 25.4482 || 0.8457s/step
# step: 30/46 || Total Loss: 25.6705 || 0.7909s/step
# step: 40/46 || Total Loss: 25.7465 || 0.8296s/step
# Finish Training.
# Start Validation.
# Finish Validation
# Total Loss: 24.9442 || Val Loss: 15.4564
#
# ----------Train one epoch.----------
# Epoch:19/20
# Start Training.
# step: 01/46 || Total Loss: 20.0220 || 0.7999s/step
# step: 10/46 || Total Loss: 23.4432 || 0.8597s/step
# step: 20/46 || Total Loss: 22.9142 || 0.6978s/step
# step: 30/46 || Total Loss: 23.9567 || 0.7965s/step
# step: 40/46 || Total Loss: 24.4835 || 0.8266s/step
# Finish Training.
# Start Validation.
# Finish Validation
# Total Loss: 23.7131 || Val Loss: 14.6097
#
# ----------Train one epoch.----------
# Epoch:20/20
# Start Training.
# step: 01/46 || Total Loss: 25.6547 || 0.8270s/step
# step: 10/46 || Total Loss: 23.2966 || 0.8220s/step
# step: 20/46 || Total Loss: 23.7653 || 0.7757s/step
# step: 30/46 || Total Loss: 23.9048 || 0.7188s/step
# step: 40/46 || Total Loss: 24.0247 || 0.8028s/step
# Finish Training.
# Start Validation.
# Finish Validation
# Total Loss: 22.7862 || Val Loss: 13.3968
#
# ----------Train one epoch.----------
# Epoch:21/40
# Start Training.
# step: 01/94 || Total Loss: 20.9996 || 0.5175s/step
# step: 10/94 || Total Loss: 24.7154 || 0.5221s/step
# step: 20/94 || Total Loss: 24.6259 || 0.5373s/step
# step: 30/94 || Total Loss: 22.7298 || 0.5960s/step
# step: 40/94 || Total Loss: 22.1674 || 0.5357s/step
# step: 50/94 || Total Loss: 22.8370 || 0.5451s/step
# step: 60/94 || Total Loss: 22.3343 || 0.5568s/step
# step: 70/94 || Total Loss: 21.6939 || 0.5461s/step
# step: 80/94 || Total Loss: 21.5529 || 0.5716s/step
# step: 90/94 || Total Loss: 21.2599 || 0.5419s/step
# Finish Training.
# Start Validation.
# Finish Validation
# Total Loss: 21.3006 || Val Loss: 9.5892
#
# ----------Train one epoch.----------
# Epoch:22/40
# Start Training.
# step: 01/94 || Total Loss: 14.2254 || 0.6248s/step
# step: 10/94 || Total Loss: 20.6029 || 0.5742s/step
# step: 20/94 || Total Loss: 17.7671 || 0.4723s/step
# step: 30/94 || Total Loss: 15.5254 || 0.4997s/step
# step: 40/94 || Total Loss: 15.8870 || 0.5233s/step
# step: 50/94 || Total Loss: 15.9656 || 0.4727s/step
# step: 60/94 || Total Loss: 15.5453 || 0.5105s/step
# step: 70/94 || Total Loss: 15.6589 || 0.5308s/step
# step: 80/94 || Total Loss: 15.1074 || 0.4989s/step
# step: 90/94 || Total Loss: 15.4209 || 0.5707s/step
# Finish Training.
# Start Validation.
# Finish Validation
# Total Loss: 15.4114 || Val Loss: 8.4576
#
# ----------Train one epoch.----------
# Epoch:23/40
# Start Training.
# step: 01/94 || Total Loss: 7.1572 || 0.5957s/step
# step: 10/94 || Total Loss: 13.5364 || 0.4903s/step
# step: 20/94 || Total Loss: 15.1200 || 0.5207s/step
# step: 30/94 || Total Loss: 14.6016 || 0.4920s/step
# step: 40/94 || Total Loss: 13.4570 || 0.5549s/step
# step: 50/94 || Total Loss: 13.3831 || 0.5123s/step
# step: 60/94 || Total Loss: 13.6943 || 0.5491s/step
# step: 70/94 || Total Loss: 13.7918 || 0.5415s/step
# step: 80/94 || Total Loss: 13.9850 || 0.4919s/step
# step: 90/94 || Total Loss: 13.7818 || 0.4769s/step
# Finish Training.
# Start Validation.
# Finish Validation
# Total Loss: 13.7019 || Val Loss: 8.3858
#
# ----------Train one epoch.----------
# Epoch:24/40
# Start Training.
# step: 01/94 || Total Loss: 32.1245 || 0.6986s/step
# step: 10/94 || Total Loss: 18.8002 || 0.4729s/step
# step: 20/94 || Total Loss: 15.9771 || 0.5316s/step
# step: 30/94 || Total Loss: 16.9318 || 0.5093s/step
# step: 40/94 || Total Loss: 15.9334 || 0.5303s/step
# step: 50/94 || Total Loss: 16.0773 || 0.5371s/step
# step: 60/94 || Total Loss: 15.4100 || 0.4825s/step
# step: 70/94 || Total Loss: 15.5365 || 0.5356s/step
# step: 80/94 || Total Loss: 14.9858 || 0.5304s/step
# step: 90/94 || Total Loss: 15.8571 || 0.4946s/step
# Finish Training.
# Start Validation.
# Finish Validation
# Total Loss: 15.5505 || Val Loss: 8.4502
#
# ----------Train one epoch.----------
# Epoch:25/40
# Start Training.
# step: 01/94 || Total Loss: 20.0285 || 0.6288s/step
# step: 10/94 || Total Loss: 13.9328 || 0.5043s/step
# step: 20/94 || Total Loss: 12.2270 || 0.4948s/step
# step: 30/94 || Total Loss: 13.4422 || 0.5115s/step
# step: 40/94 || Total Loss: 13.1303 || 0.5042s/step
# step: 50/94 || Total Loss: 13.9462 || 0.4966s/step
# step: 60/94 || Total Loss: 13.8861 || 0.5198s/step
# step: 70/94 || Total Loss: 13.8314 || 0.5010s/step
# step: 80/94 || Total Loss: 13.8199 || 0.5159s/step
# step: 90/94 || Total Loss: 13.6622 || 0.5517s/step
# Finish Training.
# Start Validation.
# Finish Validation
# Total Loss: 13.7475 || Val Loss: 7.0613
#
# ----------Train one epoch.----------
# Epoch:26/40
# Start Training.
# step: 01/94 || Total Loss: 17.6514 || 0.6175s/step
# step: 10/94 || Total Loss: 9.8636 || 0.5240s/step
# step: 20/94 || Total Loss: 10.3478 || 0.5421s/step
# step: 30/94 || Total Loss: 11.8806 || 0.4904s/step
# step: 40/94 || Total Loss: 12.9887 || 0.4959s/step
# step: 50/94 || Total Loss: 13.6475 || 0.5577s/step
# step: 60/94 || Total Loss: 13.7687 || 0.5332s/step
# step: 70/94 || Total Loss: 14.3415 || 0.5158s/step
# step: 80/94 || Total Loss: 14.1932 || 0.4969s/step
# step: 90/94 || Total Loss: 13.7623 || 0.5077s/step
# Finish Training.
# Start Validation.
# Finish Validation
# Total Loss: 13.9773 || Val Loss: 7.3714
#
# ----------Train one epoch.----------
# Epoch:27/40
# Start Training.
# step: 01/94 || Total Loss: 7.0661 || 0.5891s/step
# step: 10/94 || Total Loss: 11.9680 || 0.5525s/step
# step: 20/94 || Total Loss: 12.3138 || 0.5203s/step
# step: 30/94 || Total Loss: 12.9346 || 0.5405s/step
# step: 40/94 || Total Loss: 12.8973 || 0.4929s/step
# step: 50/94 || Total Loss: 13.2791 || 0.5259s/step
# step: 60/94 || Total Loss: 13.1548 || 0.5639s/step
# step: 70/94 || Total Loss: 14.0129 || 0.5154s/step
# step: 80/94 || Total Loss: 14.4844 || 0.5903s/step
# step: 90/94 || Total Loss: 14.7542 || 0.5063s/step
# Finish Training.
# Start Validation.
# Finish Validation
# Total Loss: 14.5136 || Val Loss: 7.3792
#
# ----------Train one epoch.----------
# Epoch:28/40
# Start Training.
# step: 01/94 || Total Loss: 6.9671 || 0.6026s/step
# step: 10/94 || Total Loss: 8.0785 || 0.7121s/step
# step: 20/94 || Total Loss: 10.7006 || 0.5573s/step
# step: 30/94 || Total Loss: 9.8365 || 0.5134s/step
# step: 40/94 || Total Loss: 10.3269 || 0.4885s/step
# step: 50/94 || Total Loss: 10.6336 || 0.5082s/step
# step: 60/94 || Total Loss: 10.7867 || 0.5482s/step
# step: 70/94 || Total Loss: 11.3680 || 0.5139s/step
# step: 80/94 || Total Loss: 11.4896 || 0.5322s/step
# step: 90/94 || Total Loss: 12.0263 || 0.5522s/step
# Finish Training.
# Start Validation.
# Finish Validation
# Total Loss: 11.8071 || Val Loss: 7.2458
#
# ----------Train one epoch.----------
# Epoch:29/40
# Start Training.
# step: 01/94 || Total Loss: 7.7036 || 0.6166s/step
# step: 10/94 || Total Loss: 11.7120 || 0.5162s/step
# step: 20/94 || Total Loss: 13.2269 || 0.4619s/step
# step: 30/94 || Total Loss: 13.5448 || 0.5150s/step
# step: 40/94 || Total Loss: 12.4429 || 0.4772s/step
# step: 50/94 || Total Loss: 12.8146 || 0.4803s/step
# step: 60/94 || Total Loss: 11.7462 || 0.4757s/step
# step: 70/94 || Total Loss: 11.9136 || 0.5011s/step
# step: 80/94 || Total Loss: 12.1757 || 0.5037s/step
# step: 90/94 || Total Loss: 12.0276 || 0.5385s/step
# Finish Training.
# Start Validation.
# Finish Validation
# Total Loss: 11.9982 || Val Loss: 6.6228
#
# ----------Train one epoch.----------
# Epoch:30/40
# Start Training.
# step: 01/94 || Total Loss: 5.0141 || 0.5490s/step
# step: 10/94 || Total Loss: 15.8156 || 0.5201s/step
# step: 20/94 || Total Loss: 15.6073 || 0.4579s/step
# step: 30/94 || Total Loss: 13.6972 || 0.4699s/step
# step: 40/94 || Total Loss: 12.6478 || 0.4832s/step
# step: 50/94 || Total Loss: 12.2118 || 0.4645s/step
# step: 60/94 || Total Loss: 13.1456 || 0.5466s/step
# step: 70/94 || Total Loss: 13.0930 || 0.5163s/step
# step: 80/94 || Total Loss: 13.2561 || 0.5614s/step
# step: 90/94 || Total Loss: 12.8623 || 0.4333s/step
# Finish Training.
# Start Validation.
# Finish Validation
# Total Loss: 12.5571 || Val Loss: 7.4581
#
# ----------Train one epoch.----------
# Epoch:31/40
# Start Training.
# step: 01/94 || Total Loss: 6.8412 || 0.5745s/step
# step: 10/94 || Total Loss: 14.6067 || 0.5250s/step
# step: 20/94 || Total Loss: 16.1469 || 0.5738s/step
# step: 30/94 || Total Loss: 14.5900 || 0.5908s/step
# step: 40/94 || Total Loss: 13.4077 || 0.5004s/step
# step: 50/94 || Total Loss: 12.8181 || 0.4576s/step
# step: 60/94 || Total Loss: 12.4326 || 0.4762s/step
# step: 70/94 || Total Loss: 11.8606 || 0.5742s/step
# step: 80/94 || Total Loss: 11.6606 || 0.4971s/step
# step: 90/94 || Total Loss: 11.4922 || 0.4910s/step
# Finish Training.
# Start Validation.
# Finish Validation
# Total Loss: 11.8216 || Val Loss: 6.9402
#
# ----------Train one epoch.----------
# Epoch:32/40
# Start Training.
# step: 01/94 || Total Loss: 11.7869 || 0.6099s/step
# step: 10/94 || Total Loss: 10.6459 || 0.5056s/step
# step: 20/94 || Total Loss: 10.5821 || 0.4997s/step
# step: 30/94 || Total Loss: 13.6374 || 0.5470s/step
# step: 40/94 || Total Loss: 12.7330 || 0.5326s/step
# step: 50/94 || Total Loss: 13.9024 || 0.5154s/step
# step: 60/94 || Total Loss: 13.5299 || 0.5187s/step
# step: 70/94 || Total Loss: 12.9172 || 0.5552s/step
# step: 80/94 || Total Loss: 13.0661 || 0.5017s/step
# step: 90/94 || Total Loss: 12.3498 || 0.5253s/step
# Finish Training.
# Start Validation.
# Finish Validation
# Total Loss: 12.2074 || Val Loss: 7.3894
#
# ----------Train one epoch.----------
# Epoch:33/40
# Start Training.
# step: 01/94 || Total Loss: 15.9136 || 0.5820s/step
# step: 10/94 || Total Loss: 13.9876 || 0.4600s/step
# step: 20/94 || Total Loss: 12.1427 || 0.4735s/step
# step: 30/94 || Total Loss: 10.7927 || 0.4698s/step
# step: 40/94 || Total Loss: 13.1266 || 0.4637s/step
# step: 50/94 || Total Loss: 13.3214 || 0.4843s/step
# step: 60/94 || Total Loss: 13.3548 || 0.5226s/step
# step: 70/94 || Total Loss: 13.3628 || 0.5316s/step
# step: 80/94 || Total Loss: 13.4758 || 0.5648s/step
# step: 90/94 || Total Loss: 13.4899 || 0.5237s/step
# Finish Training.
# Start Validation.
# Finish Validation
# Total Loss: 13.1623 || Val Loss: 6.2023
#
# ----------Train one epoch.----------
# Epoch:34/40
# Start Training.
# step: 01/94 || Total Loss: 7.4122 || 0.5692s/step
# step: 10/94 || Total Loss: 14.4474 || 0.5387s/step
# step: 20/94 || Total Loss: 12.1347 || 0.4845s/step
# step: 30/94 || Total Loss: 11.0676 || 0.5272s/step
# step: 40/94 || Total Loss: 10.4508 || 0.4923s/step
# step: 50/94 || Total Loss: 10.3952 || 0.5123s/step
# step: 60/94 || Total Loss: 11.2237 || 0.4950s/step
# step: 70/94 || Total Loss: 11.5283 || 0.4798s/step
# step: 80/94 || Total Loss: 11.3409 || 0.4723s/step
# step: 90/94 || Total Loss: 11.0696 || 0.4623s/step
# Finish Training.
# Start Validation.
# Finish Validation
# Total Loss: 11.0549 || Val Loss: 6.2118
#
# ----------Train one epoch.----------
# Epoch:35/40
# Start Training.
# step: 01/94 || Total Loss: 12.7643 || 0.6243s/step
# step: 10/94 || Total Loss: 10.0148 || 0.4905s/step
# step: 20/94 || Total Loss: 9.2934 || 0.5316s/step
# step: 30/94 || Total Loss: 11.7635 || 0.5282s/step
# step: 40/94 || Total Loss: 11.3607 || 0.4587s/step
# step: 50/94 || Total Loss: 10.6281 || 0.5126s/step
# step: 60/94 || Total Loss: 10.5523 || 0.4756s/step
# step: 70/94 || Total Loss: 10.7296 || 0.4848s/step
# step: 80/94 || Total Loss: 10.4704 || 0.5325s/step
# step: 90/94 || Total Loss: 10.8085 || 0.5540s/step
# Finish Training.
# Start Validation.
# Finish Validation
# Total Loss: 10.7012 || Val Loss: 6.0334
#
# ----------Train one epoch.----------
# Epoch:36/40
# Start Training.
# step: 01/94 || Total Loss: 6.2373 || 0.5508s/step
# step: 10/94 || Total Loss: 18.1635 || 0.5227s/step
# step: 20/94 || Total Loss: 13.7010 || 0.5400s/step
# step: 30/94 || Total Loss: 15.0933 || 0.5426s/step
# step: 40/94 || Total Loss: 13.0643 || 0.4739s/step
# step: 50/94 || Total Loss: 11.9954 || 0.4864s/step
# step: 60/94 || Total Loss: 12.0578 || 0.5171s/step
# step: 70/94 || Total Loss: 12.3037 || 0.5070s/step
# step: 80/94 || Total Loss: 11.9268 || 0.4785s/step
# step: 90/94 || Total Loss: 12.4918 || 0.5278s/step
# Finish Training.
# Start Validation.
# Finish Validation
# Total Loss: 12.8451 || Val Loss: 6.3821
#
# ----------Train one epoch.----------
# Epoch:37/40
# Start Training.
# step: 01/94 || Total Loss: 15.8178 || 0.6147s/step
# step: 10/94 || Total Loss: 9.8727 || 0.4794s/step
# step: 20/94 || Total Loss: 9.3436 || 0.4924s/step
# step: 30/94 || Total Loss: 9.4631 || 0.6166s/step
# step: 40/94 || Total Loss: 8.3313 || 0.5477s/step
# step: 50/94 || Total Loss: 9.0313 || 0.5148s/step
# step: 60/94 || Total Loss: 9.0760 || 0.5383s/step
# step: 70/94 || Total Loss: 9.3012 || 0.5007s/step
# step: 80/94 || Total Loss: 9.1199 || 0.5064s/step
# step: 90/94 || Total Loss: 8.7699 || 0.4782s/step
# Finish Training.
# Start Validation.
# Finish Validation
# Total Loss: 8.5922 || Val Loss: 6.2518
#
# ----------Train one epoch.----------
# Epoch:38/40
# Start Training.
# step: 01/94 || Total Loss: 4.8218 || 0.6257s/step
# step: 10/94 || Total Loss: 11.8033 || 0.4980s/step
# step: 20/94 || Total Loss: 12.3749 || 0.5107s/step
# step: 30/94 || Total Loss: 11.9316 || 0.5065s/step
# step: 40/94 || Total Loss: 11.0244 || 0.5477s/step
# step: 50/94 || Total Loss: 11.3604 || 0.5616s/step
# step: 60/94 || Total Loss: 12.3545 || 0.4934s/step
# step: 70/94 || Total Loss: 11.8648 || 0.5399s/step
# step: 80/94 || Total Loss: 12.3596 || 0.5188s/step
# step: 90/94 || Total Loss: 12.7090 || 0.5059s/step
# Finish Training.
# Start Validation.
# Finish Validation
# Total Loss: 12.6226 || Val Loss: 6.7680
#
# ----------Train one epoch.----------
# Epoch:39/40
# Start Training.
# step: 01/94 || Total Loss: 14.7467 || 0.5867s/step
# step: 10/94 || Total Loss: 10.6318 || 0.5346s/step
# step: 20/94 || Total Loss: 8.6742 || 0.4765s/step
# step: 30/94 || Total Loss: 8.6399 || 0.5305s/step
# step: 40/94 || Total Loss: 9.0226 || 0.4869s/step
# step: 50/94 || Total Loss: 9.1878 || 0.4990s/step
# step: 60/94 || Total Loss: 9.0078 || 0.4599s/step
# step: 70/94 || Total Loss: 8.3750 || 0.5090s/step
# step: 80/94 || Total Loss: 8.6618 || 0.5047s/step
# step: 90/94 || Total Loss: 8.5888 || 0.4679s/step
# Finish Training.
# Start Validation.
# Finish Validation
# Total Loss: 8.8168 || Val Loss: 6.3842
#
# ----------Train one epoch.----------
# Epoch:40/40
# Start Training.
# step: 01/94 || Total Loss: 13.9450 || 0.6179s/step
# step: 10/94 || Total Loss: 14.6554 || 0.5244s/step
# step: 20/94 || Total Loss: 13.2957 || 0.5418s/step
# step: 30/94 || Total Loss: 12.1209 || 0.4943s/step
# step: 40/94 || Total Loss: 11.2194 || 0.5327s/step
# step: 50/94 || Total Loss: 11.0073 || 0.5188s/step
# step: 60/94 || Total Loss: 11.5769 || 0.5601s/step
# step: 70/94 || Total Loss: 11.8194 || 0.4824s/step
# step: 80/94 || Total Loss: 11.6212 || 0.5145s/step
# step: 90/94 || Total Loss: 10.9376 || 0.4960s/step
# Finish Training.
# Start Validation.
# Finish Validation
# Total Loss: 11.4203 || Val Loss: 6.2513

# %%
# Plot the losses

total_loss_path = './loss_data/total_loss_adam_cs_40.csv'
val_loss_path = './loss_data/val_loss_adam_cs_40.csv'

with open(total_loss_path, 'r') as f:
    tl = [float(i) for i in f.read().split('\n')[:-1]]
with open(val_loss_path, 'r') as f:
    vl = [float(i) for i in f.read().split('\n')[:-1]]

fig = plt.figure(figsize = (24, 8), dpi = 100)
fig.add_subplot(1, 2, 1)
plt.semilogy(tl, label = 'Train Loss')
plt.semilogy(vl, label = 'Validation Loss')
plt.xlabel('Epochs', fontsize=16)
plt.ylabel('Loss', fontsize=16)
plt.legend()
plt.title('YOLO V4 - 40 epochs - Adam optim', fontsize=20)

total_loss_path = './loss_data/total_loss_sgd_cs_40.csv'
val_loss_path = './loss_data/val_loss_sgd_cs_40.csv'

with open(total_loss_path, 'r') as f:
    tl = [float(i) for i in f.read().split('\n')[:-1]]
with open(val_loss_path, 'r') as f:
    vl = [float(i) for i in f.read().split('\n')[:-1]]

fig.add_subplot(1, 2, 2)
plt.semilogy(tl, label = 'Train Loss')
plt.semilogy(vl, label = 'Validation Loss')
plt.xlabel('Epochs', fontsize=16)
plt.ylabel('Loss', fontsize=16)
plt.legend()
plt.title('YOLO V4 - 40 epochs - SGD optim', fontsize=20)

# fig = plt.figure(figsize = (10, 10), dpi = 80)
# fig.add_subplot(2, 1, 1)
# plt.semilogy(tl)
# plt.xlabel('Epochs')
# plt.ylabel('Train Loss')
# fig.add_subplot(2, 1, 2)
# plt.semilogy(vl)
# plt.xlabel('Epochs')
# plt.ylabel('Val Loss')
# Out:
# Text(0.5, 1.0, 'YOLO V4 - 40 epochs - SGD optim')
